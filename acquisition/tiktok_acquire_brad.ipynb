# %%
import acquire
import env
import env
from env import api
from tikapi import TikAPI, ValidationException, ResponseException

# %%
acquire.get_trend(30)
# Out:
# Longer sessions. The cookies and IP are preserved through different requests for a longer amount of time. You should include this in order to get different posts on every request. session_id

# %%
acquire.get_hashtag('sports')
# Out:
# {'cursor': '32', 'extra': {'fatal_item_ids': [], 'logid': '2022091418513001019020804123443142', 'now': 1663181491000}, 'hasMore': True, 'itemList': [{'adAuthorization': False, 'adLabelVersion': 0, 'author': {'avatarLarger': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1656348715563014~c5_1080x1080.jpeg?x-expires=1663351200&x-signature=IyvFTos8fObo1LSjb2hf1xG%2FE6M%3D', 'avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1656348715563014~c5_720x720.jpeg?x-expires=1663351200&x-signature=PQIRxcX7lqOCnTgzr9RNBrn%2FhzE%3D', 'avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1656348715563014~c5_100x100.jpeg?x-expires=1663351200&x-signature=VKG3QctzRr5BCjYkMv5vhc0pZFM%3D', 'commentSetting': 0, 'downloadSetting': 3, 'duetSetting': 0, 'ftc': False, 'id': '6784399419476657157', 'isADVirtual': False, 'nickname': 'The Sun', 'openFavorite': False, 'privateAccount': False, 'relation': 0, 'secUid': 'MS4wLjABAAAAlpG5Hwuj6vc9iQ05ne0pqLFvZfQLINrnGS_l6
# ...

# %%
acquire.get_discover('sports')
# Out:
# The category parameter should be one of these values: users, music, hashtag category

# %%
acquire.get_discover('music')
# Out:
# {'extra': {'fatal_item_ids': [], 'logid': '2022091418533801018906604704448D9C', 'now': 1663181618000}, 'log_pb': {'impr_id': '2022091418533801018906604704448D9C'}, 'message': '', 'offset': '0', 'status': 'success', 'statusCode': 0, 'status_code': 0}
# Getting next items  0

# %%
acquire.get_keyword('sports')
# Out:
# {'hashtags': {'challengeInfoList': [{'challenge': {'coverLarger': '', 'coverMedium': '', 'coverThumb': '', 'desc': '', 'id': '7887', 'isCommerce': False, 'profileLarger': '', 'profileMedium': '', 'profileThumb': '', 'stats': {'videoCount': 2900000, 'viewCount': 108600000000}, 'title': 'sports'}, 'challengeAnnouncement': {}, 'itemList': [], 'stats': {'videoCount': 2900000, 'viewCount': 108600000000}}, {'challenge': {'coverLarger': '', 'coverMedium': '', 'coverThumb': '', 'desc': '', 'id': '684427', 'isCommerce': False, 'profileLarger': '', 'profileMedium': '', 'profileThumb': '', 'stats': {'videoCount': 15700, 'viewCount': 798700000}, 'title': 'sportschallenge'}, 'challengeAnnouncement': {}, 'itemList': [], 'stats': {'videoCount': 15700, 'viewCount': 798700000}}, {'challenge': {'coverLarger': '', 'coverMedium': '', 'coverThumb': '', 'desc': '', 'id': '22252692', 'isCommerce': False, 'profileLarger': '', 'profileMedium': '', 'profileThumb': '', 'stats': {'videoCount': 16000, 'viewCount
# ...
